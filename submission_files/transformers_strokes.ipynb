# %% [markdown]
# # This is our Training code Transformers strokes based methods. Please note we cannot uploade the huge dataset in submission so reading the files is not possible here. We can show demo in our system if needed. Also, this training takes a lot of time on PCs, and needs GPUs for training

# %%
import xml.etree.ElementTree as ET
import requests
import os
import concurrent.futures

def fetch_xml(xml_url):
    response = requests.get(xml_url)
    if response.status_code != 200:
        print(f"Failed to fetch XML: {response.status_code}")
        return None
    return response.content

def parse_xml(xml_content):
    root = ET.fromstring(xml_content)
    namespace = {'s3': 'http://doc.s3.amazonaws.com/2006-03-01'}
    base_url = "https://storage.googleapis.com/quickdraw_dataset/"

    file_urls = []
    for content in root.findall(".//s3:Contents", namespace):
        key = content.find("s3:Key", namespace).text
        if key.startswith("sketchrnn/") and key.endswith(".npz") and not key.endswith(".full.npz"):
            file_urls.append(base_url + key)
    return file_urls

def download_file(file_url, download_folder):
    file_path = os.path.join(download_folder, os.path.basename(file_url))
    if os.path.exists(file_path):
        print(f"Already exists: {file_path}")
        return

    print(f"Downloading: {file_url}")
    response = requests.get(file_url)
    if response.status_code == 200:
        with open(file_path, "wb") as f:
            f.write(response.content)
    else:
        print(f"Failed to download: {file_url}")

def download_npy_files(xml_url, download_folder):
    if not os.path.exists(download_folder):
        os.makedirs(download_folder)

    xml_content = fetch_xml(xml_url)
    if xml_content is None:
        return

    file_urls = parse_xml(xml_content)

    with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
        executor.map(lambda url: download_file(url, download_folder), file_urls)

xml_url = "https://storage.googleapis.com/quickdraw_dataset?prefix=sketchrnn/"
download_folder = "data"
download_npy_files(xml_url, download_folder)
# Out:
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/The Great Wall of China.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/The Eiffel Tower.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/The Mona Lisa.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/aircraft carrier.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/airplane.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/alarm clock.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/ambulance.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/angel.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/animal migration.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/ant.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/anvil.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/apple.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/arm.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/asparagus.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/axe.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/backpack.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/banana.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/bandage.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/barn.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/baseball bat.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/baseball.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/basket.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/basketball.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/bat.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/bathtub.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/beach.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/bear.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/beard.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/bed.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/bee.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/belt.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/bench.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/bicycle.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/binoculars.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/bird.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/birthday cake.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/blackberry.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/blueberry.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/book.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/boomerang.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/bottlecap.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/bowtie.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/bracelet.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/brain.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/bread.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/bridge.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/broccoli.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/broom.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/bucket.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/bulldozer.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/bus.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/bush.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/butterfly.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/cactus.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/cake.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/calculator.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/calendar.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/camel.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/camera.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/camouflage.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/campfire.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/candle.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/cannon.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/canoe.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/car.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/carrot.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/castle.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/cat.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/ceiling fan.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/cell phone.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/cello.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/chair.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/chandelier.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/church.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/circle.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/clarinet.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/clock.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/cloud.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/coffee cup.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/compass.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/computer.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/cookie.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/cooler.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/couch.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/cow.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/crab.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/crayon.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/crocodile.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/crown.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/cruise ship.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/cup.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/diamond.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/dishwasher.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/diving board.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/dog.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/dolphin.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/donut.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/door.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/dragon.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/dresser.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/drill.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/drums.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/duck.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/dumbbell.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/ear.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/elbow.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/elephant.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/envelope.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/eraser.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/eye.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/eyeglasses.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/face.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/fan.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/feather.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/fence.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/finger.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/fire hydrant.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/fireplace.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/firetruck.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/fish.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/flamingo.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/flashlight.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/flip flops.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/floor lamp.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/flower.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/flying saucer.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/foot.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/fork.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/frog.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/frying pan.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/garden hose.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/garden.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/giraffe.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/goatee.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/golf club.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/grapes.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/grass.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/guitar.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/hamburger.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/hammer.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/hand.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/harp.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/hat.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/headphones.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/hedgehog.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/helicopter.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/helmet.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/hexagon.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/hockey puck.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/hockey stick.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/horse.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/hospital.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/hot air balloon.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/hot dog.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/hot tub.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/hourglass.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/house plant.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/house.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/hurricane.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/ice cream.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/jacket.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/jail.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/kangaroo.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/key.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/keyboard.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/knee.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/knife.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/ladder.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/lantern.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/laptop.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/leaf.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/leg.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/light bulb.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/lighter.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/lighthouse.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/lightning.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/line.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/lion.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/lipstick.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/lobster.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/lollipop.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/mailbox.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/map.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/marker.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/matches.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/megaphone.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/mermaid.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/microphone.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/microwave.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/monkey.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/moon.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/mosquito.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/motorbike.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/mountain.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/mouse.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/moustache.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/mouth.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/mug.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/mushroom.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/nail.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/necklace.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/nose.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/ocean.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/octagon.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/octopus.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/onion.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/oven.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/owl.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/paint can.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/paintbrush.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/palm tree.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/panda.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/pants.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/paper clip.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/parachute.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/parrot.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/passport.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/peanut.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/pear.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/peas.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/pencil.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/penguin.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/piano.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/pickup truck.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/picture frame.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/pig.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/pillow.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/pineapple.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/pizza.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/pliers.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/police car.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/pond.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/pool.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/popsicle.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/postcard.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/potato.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/power outlet.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/purse.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/rabbit.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/raccoon.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/radio.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/rain.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/rainbow.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/rake.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/remote control.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/rhinoceros.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/rifle.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/river.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/roller coaster.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/rollerskates.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/sailboat.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/sandwich.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/saw.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/saxophone.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/school bus.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/scissors.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/scorpion.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/screwdriver.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/sea turtle.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/see saw.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/shark.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/sheep.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/shoe.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/shorts.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/shovel.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/sink.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/skateboard.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/skull.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/skyscraper.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/sleeping bag.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/smiley face.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/snail.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/snake.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/snorkel.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/snowflake.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/snowman.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/soccer ball.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/sock.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/speedboat.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/spider.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/spoon.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/spreadsheet.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/square.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/squiggle.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/squirrel.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/stairs.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/star.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/steak.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/stereo.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/stethoscope.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/stitches.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/stop sign.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/stove.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/strawberry.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/streetlight.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/string bean.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/submarine.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/suitcase.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/sun.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/swan.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/sweater.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/swing set.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/sword.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/syringe.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/t-shirt.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/table.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/teapot.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/teddy-bear.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/telephone.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/television.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/tennis racquet.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/tent.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/tiger.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/toaster.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/toe.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/toilet.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/tooth.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/toothbrush.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/toothpaste.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/tornado.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/tractor.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/traffic light.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/train.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/tree.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/triangle.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/trombone.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/truck.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/trumpet.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/umbrella.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/underwear.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/van.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/vase.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/violin.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/washing machine.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/watermelon.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/waterslide.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/whale.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/wheel.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/windmill.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/wine bottle.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/wine glass.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/wristwatch.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/yoga.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/zebra.npz
# Downloading: https://storage.googleapis.com/quickdraw_dataset/sketchrnn/zigzag.npz

# %%
# import
import numpy as np
import os
from sklearn.utils import shuffle
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
import tensorflow as tf
from tensorflow.keras import layers, models

DATA_DIR = '/content/data'
MAX_CLASSES = 345
MAX_SAMPLES_PER_CLASS = 80000
MAX_SEQ_LEN = 130
POINT_DIM = 3

# %%
data = np.load('data/camera.npz', allow_pickle=True, encoding='latin1')
sample = data['train']
print(len(sample))
# Out:
# 70000

# %%
def preprocess_stroke(stroke, max_len=MAX_SEQ_LEN):
    stroke = stroke.astype(np.float32)
    stroke[:, 0] = np.cumsum(stroke[:, 0])
    stroke[:, 1] = np.cumsum(stroke[:, 1])
    stroke[:, 0] -= stroke[:, 0].mean()
    stroke[:, 1] -= stroke[:, 1].mean()

    if len(stroke) > max_len:
        # stroke too big, we reduce to max sizee
        stroke = stroke[:max_len]
    else:
        pad = np.zeros((max_len - len(stroke), 3), dtype=np.float32)
        stroke = np.vstack([stroke, pad])  # we pad to make all same

    return stroke

def load_data(data_dir, max_classes, max_samples_per_class):
    # we only get files who end like .npz, not other file
    files = sorted([f for f in os.listdir(data_dir) if f.endswith('.npz')])[:max_classes]
    X, y = [], []

    for class_id, file in enumerate(files):
        data = np.load(os.path.join(data_dir, file), allow_pickle=True, encoding="latin1")
        for stroke in data['train'][:max_samples_per_class]:
            X.append(preprocess_stroke(stroke))
            y.append(class_id)

    X = np.array(X, dtype=np.float32)
    y = to_categorical(y, num_classes=max_classes)
    return shuffle(X, y, random_state=42)  # shuffle all so model no memorize order

# %%
from keras.saving import register_keras_serializable

@register_keras_serializable()
class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.ff_dim = ff_dim
        self.rate = rate

        self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = tf.keras.Sequential([
            layers.Dense(ff_dim, activation='relu'),
            layers.Dense(embed_dim),
        ])
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs, training=None):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)  # we do mix input and attention, then fix with norm
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)  # again mix and norm to make nice output

    def get_config(self):
        config = super().get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "num_heads": self.num_heads,
            "ff_dim": self.ff_dim,
            "rate": self.rate
        })
        return config


@register_keras_serializable()
class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self, maxlen, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.maxlen = maxlen
        self.embed_dim = embed_dim
        self.pos_embedding = self.add_weight(
            name="pos_embedding",
            shape=(1, maxlen, embed_dim),
            initializer="random_normal"  # just put some noise to start, learn later
        )

    def call(self, x):
        return x + self.pos_embedding  # we add position info so model

    def get_config(self):
        config = super().get_config()
        config.update({
            "maxlen": self.maxlen,
            "embed_dim": self.embed_dim
        })
        return config


def build_transformer_model(seq_len=130, input_dim=3, num_classes=50, embed_dim=128, num_heads=4, ff_dim=256):
    inputs = layers.Input(shape=(seq_len, input_dim))
    x = layers.Dense(embed_dim)(inputs)
    x = PositionalEncoding(seq_len, embed_dim)(x)

    for _ in range(2):
        x = TransformerBlock(embed_dim, num_heads, ff_dim)(x)

    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs=inputs, outputs=outputs)  # buld full model with all that transformer stuff
    return model

# %%
model = build_transformer_model()
model.summary()


#lead data
X, y = load_data(DATA_DIR, MAX_CLASSES, MAX_SAMPLES_PER_CLASS)
split = int(0.9 * len(X))
X_train, X_val = X[:split], X[split:]
y_train, y_val = y[:split], y[split:]

# %%
from tensorflow.keras.optimizers.schedules import ExponentialDecay
#setting upa scheduler to decay the learning rate so make model fit best
lr_schedule = ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=10000,
    decay_rate=0.9,
    staircase=True
)

optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule, clipnorm=1.0)
# from tensorflow.keras.optimizers import AdamW

# optimizer = tf.keras.optimizers.Adam(learning_rate=1e-2, clipnorm=1.0)

model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Train the model and save best nodel
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

callbacks = [
    ModelCheckpoint("best_transformer_model.keras", monitor="val_accuracy", save_best_only=True),
    EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3)
]

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    batch_size=256,
    epochs=15,
    callbacks=callbacks
)
# Out:
# Epoch 1/15
# 1758/1758 ━━━━━━━━━━━━━━━━━━━━ 218s 114ms/step - accuracy: 0.3135 - loss: 2.5410 - val_accuracy: 0.5400 - val_loss: 1.6487 - learning_rate: 0.0010
# Epoch 2/15
# 1758/1758 ━━━━━━━━━━━━━━━━━━━━ 244s 110ms/step - accuracy: 0.5316 - loss: 1.6916 - val_accuracy: 0.6006 - val_loss: 1.4049 - learning_rate: 0.0010
# Epoch 3/15
# 1758/1758 ━━━━━━━━━━━━━━━━━━━━ 197s 107ms/step - accuracy: 0.5913 - loss: 1.4673 - val_accuracy: 0.6514 - val_loss: 1.2443 - learning_rate: 0.0010
# Epoch 4/15
# 1758/1758 ━━━━━━━━━━━━━━━━━━━━ 205s 109ms/step - accuracy: 0.6222 - loss: 1.3513 - val_accuracy: 0.6523 - val_loss: 1.2264 - learning_rate: 0.0010
# Epoch 5/15
# 1758/1758 ━━━━━━━━━━━━━━━━━━━━ 185s 105ms/step - accuracy: 0.6471 - loss: 1.2675 - val_accuracy: 0.6802 - val_loss: 1.1398 - learning_rate: 0.0010
# Epoch 6/15
# 1758/1758 ━━━━━━━━━━━━━━━━━━━━ 185s 105ms/step - accuracy: 0.6631 - loss: 1.2042 - val_accuracy: 0.7017 - val_loss: 1.0590 - learning_rate: 9.0000e-04
# Epoch 7/15
# 1758/1758 ━━━━━━━━━━━━━━━━━━━━ 185s 105ms/step - accuracy: 0.6812 - loss: 1.1359 - val_accuracy: 0.7050 - val_loss: 1.0437 - learning_rate: 9.0000e-04
# Epoch 8/15
# 1758/1758 ━━━━━━━━━━━━━━━━━━━━ 185s 105ms/step - accuracy: 0.6901 - loss: 1.1083 - val_accuracy: 0.7148 - val_loss: 1.0148 - learning_rate: 9.0000e-04
# Epoch 9/15
# 1758/1758 ━━━━━━━━━━━━━━━━━━━━ 203s 106ms/step - accuracy: 0.6999 - loss: 1.0730 - val_accuracy: 0.7244 - val_loss: 0.9844 - learning_rate: 9.0000e-04
# Epoch 10/15
# 1758/1758 ━━━━━━━━━━━━━━━━━━━━ 206s 108ms/step - accuracy: 0.7097 - loss: 1.0357 - val_accuracy: 0.7252 - val_loss: 0.9794 - learning_rate: 9.0000e-04
# Epoch 11/15
# 1758/1758 ━━━━━━━━━━━━━━━━━━━━ 202s 108ms/step - accuracy: 0.7137 - loss: 1.0209 - val_accuracy: 0.7345 - val_loss: 0.9455 - learning_rate: 9.0000e-04
# Epoch 12/15
# 1758/1758 ━━━━━━━━━━━━━━━━━━━━ 185s 105ms/step - accuracy: 0.7180 - loss: 1.0068 - val_accuracy: 0.7348 - val_loss: 0.9434 - learning_rate: 8.1000e-04
# Epoch 13/15
# 1758/1758 ━━━━━━━━━━━━━━━━━━━━ 188s 107ms/step - accuracy: 0.7284 - loss: 0.9695 - val_accuracy: 0.7439 - val_loss: 0.9176 - learning_rate: 8.1000e-04
# Epoch 14/15
# 1758/1758 ━━━━━━━━━━━━━━━━━━━━ 203s 108ms/step - accuracy: 0.7300 - loss: 0.9671 - val_accuracy: 0.7446 - val_loss: 0.9177 - learning_rate: 8.1000e-04
# Epoch 15/15
# 1758/1758 ━━━━━━━━━━━━━━━━━━━━ 202s 108ms/step - accuracy: 0.7347 - loss: 0.9471 - val_accuracy: 0.7486 - val_loss: 0.8987 - learning_rate: 8.1000e-04

# %%
from tensorflow.keras.models import load_model

from tensorflow.keras.models import load_model

model = load_model("best_transformer_model.keras", custom_objects={
    "PositionalEncoding": PositionalEncoding,
    "TransformerBlock": TransformerBlock
})


history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    initial_epoch=15,  # (optional)
    epochs=30,
    batch_size=256,
    callbacks=callbacks
)

# %%
# chck accruacy
val_loss, val_acc = model.evaluate(X_val, y_val)
print("Validation Accuracy:", val_acc)
# Out:
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.7614 - loss: 0.8470
# Validation Accuracy: 0.7626399993896484
